# %%
#1. Write a Python program to find maximum between two numbers.
num1=int(input("enter first number:"))
num2=int(input("enter second number:"))
greatest=num1
if num1<num2:
    greatest=num2
else:
    greatest=num1

print(greatest)
# Out:
# 3

# %%
#2. Write a Python program to find maximum among three numbers.
n1=int(input("enter a number"))
n2=int(input("enter a number"))
n3=int(input("enter a number"))
if n1>n2 and n1>n3:
    greatest=n1
elif n2>n1 and n2>n3:
    greatest=n2
else:
    greatest=n3

print(greatest)
# Out:
# 14

# %%
#3. Write a Python program to check whether a number is negative, positive or zero
no=int(input("enter a number"))
if no>0:
    print("it is positeve")
elif no<0:
    print("it is negative")  
else:
    print("it is zero")
# Out:
# it is zero

# %%
#4. Write a Python program to check whether a number is divisible by 5 and 11 or not
no=int(input('enter a number'))
if no%5==0 and no%11==0:
    print("it is divisible by 5 and 11")
# Out:
# it is divisible by 5 and 11

# %%
#5. Write a Python program to check whether a number is even or odd.
no=int(input("enter the number"))
if no%2==0:
    print("it is even")
else:
    print("it is odd")
# Out:
# it is even

# %%
#6. Write a Python program to check whether a year is leap year or not.
ye=int(input("enter the year"))
x=str(ye)
y=x[2:]
print(y)
if int(y)%4==0 or int(y)==00:
    print("it is a leap year")




# if right(ye,2)%4==0:
#     print("it is leap")
# Out:
# 04
# it is a leap year

# %%
#7. Write a Python program to check whether a character is alphabet or not.
chara=input("enter character")
if chara.isalpha():
    print("it is an alphabet")
else:
    print("it is not an character")
# Out:
# it is an alphabet

# %%
#8. Write a Python program to input any alphabet and check whether it is
#vowel or consonant.

chara=input("enter the character")
vowel="aeiou"
if chara.lower() in vowel:
    print("it is vowel")
else:
    print("it is a consonent")
# Out:
# it is a consonent

# %%
# 9. Write a Python program to check whether a character is uppercase or
# lowercase alphabet.

chra=input("enter a character")
if chra.isupper():
    print("it is an uppercase letter")
else:
    print("it is an lowercase letter")
# Out:
# it is an uppercase letter

# %%
#10. Write a Python program to count total number of notes in given amount.
amount=int(input("enter amount"))
note=int(input("select note type "))

# match(note):
#     case 10:
#         print("the number of notes are: ",amount/10)
#     case 20:
#         print("the number of noter are: ",amount/20)
#     case 50:
#         print("the number of notes are: ",amount/50)
#     case __:
#         print("invalid note type")
if note==10:
    print("the number of noter are: ",amount/10)
elif note==20:
    print("the number of noter of 20 are:",amount/20)
elif note==50:
    print("the number of 50 rupee notes are :",amount/50)
else:
    print("invalid note type")
# Out:
# the number of noter are:  100.0

# %%
#11. Write a Python program to input angles of a triangle and check whether
#triangle is valid or not.

side1=int(input("enter the size of angel 1"))
side2=int(input("enter the size of angel 2"))
side3=int(input("enter the size of angel 3"))

add=side1+side2+side3
if add==180:
    print("it is a valid triangel")
else:
    print("invalid triangle")
# Out:
# it is a valid triangel

# %%
# 12. Write a Python program to input all sides of a triangle and check whether
# triangle is valid or not.
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))

if a + b > c and a + c > b and b + c > a:
    print("Triangle is valid")
else:
    print("Triangle is not valid")
# Out:
# Triangle is not valid

# %%
# 13. Write a Python program to check whether the triangle is equilateral,
# isosceles or scalene triangle.
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))

if a==b==c:
    print("it is a equilateral triangle")
elif a==b or b==c or c==a :
    print("it ia a isoceles triable")
else:
    print("scelen triangle")
# Out:
# it ia a isoceles triable

# %%
# 14. Write a Python program to calculate profit or loss. Input is selling cost and
# actual cost.

actual=int(input("enter actual cost"))
sell=int(input("enter the selling price"))

if actual>sell:
    print("the loss of:",actual-sell)
else:
    print("the profit is:",sell-actual)
# Out:
# the profit is: 20

# %%
# 15. Write a Python program to input marks of five subjects Physics, Chemistry,
# Biology, Mathematics and Computer. Calculate percentage and grade
# according to following:
# Percentage >= 90% : Grade A
# Percentage >= 80% : Grade B
# Percentage >= 70% : Grade C
# Percentage >= 60% : Grade D
# Percentage >= 40% : Grade E
# Percentage < 40% : Grade F

phy=int(input("enter the marks of physics"))
chem=int(input("enter the marks of chemistry"))
bio=int(input("enter the marks of biology"))
math=int(input("enter the marks of mathematics"))
comp=int(input("enter the marks of computer"))

summ=phy+chem+bio+math+comp

per=(summ/500)*100
print(per)
if per>=90:
    print("Grade A")
elif per>=80:
    print("Grade B")
elif per>=70:
    print("Grade C")   
elif per>=60:
    print("Grade D")
elif per>=40:
    print("Grade E")
else:
    print("Grade F")
# Out:
# 35.0
# Grade F
