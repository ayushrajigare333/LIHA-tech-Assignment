# %%
print("hello")
# Out:
# hello

# %%
print("my name is ayush")
# Out:
# my name is ayush

# %%
#PYTHON  is dynamically typed,so we dont need to declare the type of the variable 
a=10
b=10.3
c="hello"
# check the memory location
print(id(a))

print(type(a))
print(type(b))
print(type(c))
# Out:
# 140725481207192
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
#factorial
import math
print(math.factorial(5))
print(math.sqrt(68))
# Out:
# 120
# 8.246211251235321

# %%
# we can take an object kirectly
#then we need to assing a name to a object
# every thing in python is an object

# rulest to declare an identifier
#a-z, A-Z,


#assingme check pep8 styple guide
bank_name="Sbi"
#bank$name="Sbi"#not allowed,starting with number like 1bank="sbi"
_bank_name="Sbi"
print(_bank_name)


# reserved keywoard are not allowed 35 reserved keyword are there
class="sham"
as="sham"
# Out:
#   Cell In[133], line 17
#     class="sham"
#          ^
# SyntaxError: invalid syntax

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#Data types in python 14
# numeric(int,float,complex)
#booleanLbool true flase
# string
name="ayush"
print(type(name))
# Out:
# <class 'str'>

# %%
#  why we take " and ' quote for string

# When we have to use apostrpy then we will use double quote outside
print("it is amol's book")
print('it is amol's book')# here the error comes
print("he said,\"I can't come tomoroow\"")# whenever if forcefully want to use double quote then use \
# Out:
#   Cell In[19], line 5
#     print('it is amol's book')
#                             ^
# SyntaxError: unterminated string literal (detected at line 5)

# %%
print(chr(66))
# Out:
# B

# %%
print("\u0910")# this is unicode we can print in whatever language we want
# Out:
# ऐ

# %%
# methods of strig
help(str.index())

# %%
a="python is simple"
a.index('i')# gives the first occuring idex index(substring)
a.index('py')# gives the first occuring idex index(substring)
# Out:
# 0

# %%
a.startswith('a')
# Out:
# False

# %%
d='*#   python is simple'
d.strip('* #$ ')# removes the spaces and addithonally remove given parameters
# Out:
# 'python is simple'

# %%
d=("python        is    simple")
' '.join(d.split())# separted with split and give a list of strings and joined in a singel string with join function

date=['08',"aug","2026"]
"/".join(date)
# Out:
# '08/aug/2026'

# %%
name="aYuSh"
name.swapcase()# it will do upper to lower and lower to uppers
# Out:
# 'AyUsH'

# %%
#list creating empty list

name=[]
name_2=list()

# %%
g=[]
g.append("abc")# adds entire collection
g.extend("abc")# extend adds  elements
g
# Out:
# ['abc', 'a', 'b', 'c']

# %%
g.pop()# removes the last element and returns also we can pass the index
# Out:
# 'c'

# %%
g.remove('a')# remove the specific element especially first occuring

# %%
g
# Out:
# ['abc', 'b']

# %%
#shallow copy and deep copy
f=[1,2,3,4,5]
f_copy=f.copy()
f_copy
f.append(500)
f
f_copy.append(10)
f_copy
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
id(f),id(f_copy)# diffrent memory addresses
# Out:
# (2410329188800, 2410329169408)

# %%
new_copy=f# here the address become same  then all the 
new_copy
# Out:
# [1, 2, 3, 4, 5, 500]

# %%
new_copy.append(10)

f
# Out:
# [1, 2, 3, 4, 5, 500, 10]

# %%
new_copy,f # it is calles the shallow copy
# Out:
# ([1, 2, 3, 4, 5, 500, 10], [1, 2, 3, 4, 5, 500, 10])

# %%
c=[1,2,3] # used to insert element before the index
c.insert(1,21)
c
# Out:
# [1, 21, 2, 3]

# %%
#insert after 3
c.insert(4,2111)
c
# Out:
# [1, 21, 2, 3, 2111]

# %%
c.reverse()
c
# Out:
# [2111, 3, 2, 21, 1]

# %%
c.sort()
c
# Out:
# [1, 2, 3, 21, 2111]

# %%
# sort in decending
c.sort(reverse=True)
c
# Out:
# [2111, 21, 3, 2, 1]

# %% [markdown]
# # tuple

# %%
# diffrence between list and tuple
# list is mutable and tuple is immutable
# list is slower than tuple because of the mutablity

# %% [markdown]
# #set

# %%
# empty set
s=set()
s={()}
S={}# its an dict

# %%
l={1,1,1,1,1,2}# duplicates are not allowed
l
# Out:
# {1, 2}

# %%
# set does not preserve the sequence becuase the backgroup date structure is a hash table
s4={1,2,3,4,5,6,"ayush",99}
s4
# Out:
# {1, 2, 3, 4, 5, 6, 99, 'ayush'}

# %%
# in set we does not have indexing and slicing because it is unordered collection of elements
s1={()}
s1.add(100)
s1.update({400,200,300})
#s1.add({"ayush",40})
#s1.add(["ayush"]) # we cannot add mutable elements we can only add set and string
s1.update({"ayush",40})
#s1.update({"ayush",[10,20,30]})
s1.update("ayush",[10,20,30])

s1
# Out:
# {(), 10, 100, 20, 200, 30, 300, 40, 400, 'a', 'ayush', 'h', 's', 'u', 'y'}

# %%
s1={10,20,30}
s2={10,40,500}

s1.union(s2)
# Out:
# {10, 20, 30, 40, 500}

# %%
s1.intersection(s2)
# Out:
# {10}

# %%
s1.difference(s2)
# Out:
# {20, 30}

# %%
s1.symmetric_difference(s2)# it will give all the elements in s1 or s2 but not in bothd
# Out:
# {20, 30, 40, 500}

# %%
d={"name":"ayush","age":35,"city":"new"}
d.keys()
d.values()
d['salary']=45000
d["name"]="lavlu"
d
# Out:
# {'name': 'lavlu', 'age': 35, 'city': 'new', 'salary': 45000}

# %%
# dict using from keys\
dict.fromkeys(["v1","v2","v3"],100)
# Out:
# {'v1': 100, 'v2': 100, 'v3': 100}

# %%
# creating dict out of two list

list1=[10,20,30]
list2=['aysuh','ram','shma']

x=dict(zip(list1,list2))
x.setdefault("name","ayu")
x
# Out:
# {10: 'aysuh', 20: 'ram', 30: 'shma', 'name': 'ayu'}

# %%
# what is diffrence between set and frozen set
x.setdefault("name","ayu")
x.popitem()
# Out:
# 'ayu'

# %% [markdown]
# # important functions in python

# %%
print(10,20,30,sep="\t")
# Out:
# 10	20	30

# %%
print("hello all",end=' ')
print("good afternood")
# Out:
# hello all good afternood

# %%
# enumerate it gives index and value pair
li=[10,20,30,40]#((0,10),(1,20)
print(enumerate(li))
# to get output use typecastion
list(enumerate(li))
# Out:
# ...
# [(0, 10), (1, 20), (2, 30), (3, 40)]

# %%
num=int(input("enter num 1"))
print(num)
# Out:
# 3

# %%
# to take list as an input
li=eval(input("enter the list"))
print(li,type(11))
# Out:
# 11 <class 'int'>

# %%
# rounding up the numbers
num=23.44444444444444444
round(num,2)
# Out:
# 23.44

# %%
print(sum([20,30,40]))
max([20,30,40])
min([20,30,40])
sum([20,30,40])//len([20,30,40])
# Out:
# 90
# 30

# %%
sorted({10,20,30,1})# sort only work on list and sorted works on any and gives the list
sorted((10,20,30,1))
# Out:
# [1, 10, 20, 30]

# %%
t=["ashutosh","amol","shamm","prathmesh"]
sorted(t,key=len)# will sort on the basis of len of the string
# Out:
# ['amol', 'shamm', 'ashutosh', 'prathmesh']

# %% [markdown]
# ### flow control blocks

# %% [markdown]
# # selective or condtional execution if elif ese
#
# num= int(input)

# %%
# selective or condtional execution if elif ese

num= int(input("enter a num"))

if num>0:
    print("the no is positive")
elif num <0:
    print("is this negative") 
else:
    print("the number is zero")
# Out:
# is this negative

# %%
age=int(input("enter your age"))
nation=input("enter your nation")
nation=nation.lower()
if age>18 and nation=="india":
    print("you are eligble to vote")
else:
    print("you are not eligible")
# Out:
# you are eligble to vote

# %%
# to check the largest of three numbers using if else

num1=int(input("enter a no"))
num2=int(input("enter a no"))
num3=int(input("enter a no"))

greatest=num1
if num1<num2:
    greatest=num2
elif num3>num2:
    greatest=num3
else:
    greatest=num1

greatest
# Out:
# 30

# %%
# iterative statements for while
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
name='ayush'
for i in range(0,3):
    print(name)
# Out:
# ayush
# ayush
# ayush

# %%
nums=[1,20,30,40,53,33,3,31,35,37]
odd=[]
even=[]

for i in nums:
    if i%2==0:
        odd.append(i)
    else:
        even.append(i)

even,odd
# Out:
# ([1, 53, 33, 3, 31, 35, 37], [20, 30, 40])

# %%
marks="path got 80 70 60 70 marks"
x=marks.split()
l=[]
for i in marks.split():
    if i.isdigit():
        l.append(int(i))

print(l)
final=sum(l)
print("percet",final/len(l))
# Out:
# [80, 70, 60, 70]
# percet 70.0
